# %%
# %tensorflow_version 2.x
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Colab only includes TensorFlow 2.x; %tensorflow_version has no effect.
# Found GPU at: /device:GPU:0

# %%
# %tensorflow_version 2.x
import tensorflow as tf
import timeit

device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  print(
      '\n\nThis error most likely means that this notebook is not '
      'configured to use a GPU.  Change this in Notebook Settings via the '
      'command palette (cmd/ctrl-shift-P) or the Edit menu.\n\n')
  raise SystemError('GPU device not found')

def cpu():
  with tf.device('/cpu:0'):
    random_image_cpu = tf.random.normal((100, 100, 100, 3))
    net_cpu = tf.keras.layers.Conv2D(32, 7)(random_image_cpu)
    return tf.math.reduce_sum(net_cpu)

def gpu():
  with tf.device('/device:GPU:0'):
    random_image_gpu = tf.random.normal((100, 100, 100, 3))
    net_gpu = tf.keras.layers.Conv2D(32, 7)(random_image_gpu)
    return tf.math.reduce_sum(net_gpu)
  
# We run each op once to warm up; see: https://stackoverflow.com/a/45067900
cpu()
gpu()

# Run the op several times.
print('Time (s) to convolve 32x7x7x3 filter over random 100x100x100x3 images '
      '(batch x height x width x channel). Sum of ten runs.')
print('CPU (s):')
cpu_time = timeit.timeit('cpu()', number=10, setup="from __main__ import cpu")
print(cpu_time)
print('GPU (s):')
gpu_time = timeit.timeit('gpu()', number=10, setup="from __main__ import gpu")
print(gpu_time)
print('GPU speedup over CPU: {}x'.format(int(cpu_time/gpu_time)))
# Out:
# Colab only includes TensorFlow 2.x; %tensorflow_version has no effect.
# Time (s) to convolve 32x7x7x3 filter over random 100x100x100x3 images (batch x height x width x channel). Sum of ten runs.
# CPU (s):
# 0.40315580399987994
# GPU (s):
# 0.03830243599986716
# GPU speedup over CPU: 10x

# %%
# %cd /content/drive/MyDrive/IGRP_GNN/
# Out:
# /content/drive/MyDrive/copy_version_07302022_highorder_exps

# %%
# !python setup.py install
# Out:
# running install
# running bdist_egg
# running egg_info
# creating IGRP_GNN.egg-info
# writing IGRP_GNN.egg-info/PKG-INFO
# writing dependency_links to IGRP_GNN.egg-info/dependency_links.txt
# writing requirements to IGRP_GNN.egg-info/requires.txt
# writing top-level names to IGRP_GNN.egg-info/top_level.txt
# writing manifest file 'IGRP_GNN.egg-info/SOURCES.txt'
# reading manifest file 'IGRP_GNN.egg-info/SOURCES.txt'
# writing manifest file 'IGRP_GNN.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# warning: install_lib: 'build/lib' does not exist -- no Python modules to install
#
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying IGRP_GNN.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying IGRP_GNN.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying IGRP_GNN.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying IGRP_GNN.egg-info/requires.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying IGRP_GNN.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# zip_safe flag not set; analyzing archive contents...
# creating 'dist/IGRP_GNN-0.1-py3.7.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing IGRP_GNN-0.1-py3.7.egg
# Removing /usr/local/lib/python3.7/dist-packages/IGRP_GNN-0.1-py3.7.egg
# Copying IGRP_GNN-0.1-py3.7.egg to /usr/local/lib/python3.7/dist-packages
# IGRP-GNN 0.1 is already the active version in easy-install.pth
#
# Installed /usr/local/lib/python3.7/dist-packages/IGRP_GNN-0.1-py3.7.egg
# Processing dependencies for IGRP-GNN==0.1
# Searching for torchprofile==0.0.4
# Best match: torchprofile 0.0.4
# Processing torchprofile-0.0.4-py3.7.egg
# torchprofile 0.0.4 is already the active version in easy-install.pth
#
# Using /usr/local/lib/python3.7/dist-packages/torchprofile-0.0.4-py3.7.egg
# Searching for networkx==2.6.3
# Best match: networkx 2.6.3
# Adding networkx 2.6.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for mlxtend==0.14.0
# Best match: mlxtend 0.14.0
# Adding mlxtend 0.14.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for sklearn==0.0.post1
# Best match: sklearn 0.0.post1
# Processing sklearn-0.0.post1-py3.7.egg
# sklearn 0.0.post1 is already the active version in easy-install.pth
#
# Using /usr/local/lib/python3.7/dist-packages/sklearn-0.0.post1-py3.7.egg
# Searching for matplotlib==3.2.2
# Best match: matplotlib 3.2.2
# Adding matplotlib 3.2.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for scipy==1.7.3
# Best match: scipy 1.7.3
# Adding scipy 1.7.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for torch==1.12.1+cu113
# Best match: torch 1.12.1+cu113
# Adding torch 1.12.1+cu113 to easy-install.pth file
# Installing convert-caffe2-to-onnx script to /usr/local/bin
# Installing convert-onnx-to-caffe2 script to /usr/local/bin
# Installing torchrun script to /usr/local/bin
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for numpy==1.21.6
# Best match: numpy 1.21.6
# Adding numpy 1.21.6 to easy-install.pth file
# Installing f2py script to /usr/local/bin
# Installing f2py3 script to /usr/local/bin
# Installing f2py3.7 script to /usr/local/bin
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for torchvision==0.13.1+cu113
# Best match: torchvision 0.13.1+cu113
# Adding torchvision 0.13.1+cu113 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for pandas==1.3.5
# Best match: pandas 1.3.5
# Adding pandas 1.3.5 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for scikit-learn==1.0.2
# Best match: scikit-learn 1.0.2
# Adding scikit-learn 1.0.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for setuptools==57.4.0
# Best match: setuptools 57.4.0
# Adding setuptools 57.4.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for cycler==0.11.0
# Best match: cycler 0.11.0
# Adding cycler 0.11.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for kiwisolver==1.4.4
# Best match: kiwisolver 1.4.4
# Adding kiwisolver 1.4.4 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for pyparsing==3.0.9
# Best match: pyparsing 3.0.9
# Adding pyparsing 3.0.9 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for python-dateutil==2.8.2
# Best match: python-dateutil 2.8.2
# Adding python-dateutil 2.8.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for typing-extensions==4.1.1
# Best match: typing-extensions 4.1.1
# Adding typing-extensions 4.1.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for requests==2.23.0
# Best match: requests 2.23.0
# Adding requests 2.23.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for Pillow==7.1.2
# Best match: Pillow 7.1.2
# Adding Pillow 7.1.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for pytz==2022.5
# Best match: pytz 2022.5
# Adding pytz 2022.5 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for threadpoolctl==3.1.0
# Best match: threadpoolctl 3.1.0
# Adding threadpoolctl 3.1.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for joblib==1.2.0
# Best match: joblib 1.2.0
# Adding joblib 1.2.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for six==1.15.0
# Best match: six 1.15.0
# Adding six 1.15.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for chardet==3.0.4
# Best match: chardet 3.0.4
# Adding chardet 3.0.4 to easy-install.pth file
# Installing chardetect script to /usr/local/bin
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for urllib3==1.24.3
# Best match: urllib3 1.24.3
# Adding urllib3 1.24.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for certifi==2022.9.24
# Best match: certifi 2022.9.24
# Adding certifi 2022.9.24 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for idna==2.10
# Best match: idna 2.10
# Adding idna 2.10 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Finished processing dependencies for IGRP-GNN==0.1

# %%
import torch
print(torch. __version__)
# Out:
# 1.12.1+cu113

# %%
# !pip install dgl-cu113 dglgo -f https://data.dgl.ai/wheels/repo.html
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://data.dgl.ai/wheels/repo.html
# Collecting dgl-cu113
#   Downloading https://data.dgl.ai/wheels/dgl_cu113-0.9.1.post1-cp37-cp37m-manylinux1_x86_64.whl (239.2 MB)
#      |████████████████████████████████| 239.2 MB 1.4 kB/s
# Collecting dglgo
#   Downloading dglgo-0.0.2-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 1.6 MB/s
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.7/dist-packages (from dgl-cu113) (1.21.6)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from dgl-cu113) (1.7.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from dgl-cu113) (2.23.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from dgl-cu113) (4.64.1)
# Collecting psutil>=5.8.0
#   Downloading psutil-5.9.4-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (280 kB)
#      |████████████████████████████████| 280 kB 9.9 MB/s
# Requirement already satisfied: networkx>=2.1 in /usr/local/lib/python3.7/dist-packages (from dgl-cu113) (2.6.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->dgl-cu113) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->dgl-cu113) (2022.9.24)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->dgl-cu113) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->dgl-cu113) (1.24.3)
# Collecting autopep8>=1.6.0
#   Downloading autopep8-2.0.0-py2.py3-none-any.whl (45 kB)
#      |████████████████████████████████| 45 kB 4.2 MB/s
# Collecting numpydoc>=1.1.0
#   Downloading numpydoc-1.5.0-py3-none-any.whl (52 kB)
#      |████████████████████████████████| 52 kB 1.4 MB/s
# Requirement already satisfied: pydantic>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from dglgo) (1.10.2)
# Requirement already satisfied: typer>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from dglgo) (0.4.2)
# Collecting isort>=5.10.1
#   Downloading isort-5.10.1-py3-none-any.whl (103 kB)
#      |████████████████████████████████| 103 kB 91.4 MB/s
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.7/dist-packages (from dglgo) (1.0.2)
# Collecting rdkit-pypi
#   Downloading rdkit_pypi-2022.9.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29.5 MB)
#      |████████████████████████████████| 29.5 MB 904 kB/s
# Collecting ogb>=1.3.3
#   Downloading ogb-1.3.5-py3-none-any.whl (78 kB)
#      |████████████████████████████████| 78 kB 9.2 MB/s
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.7/dist-packages (from dglgo) (6.0)
# Collecting ruamel.yaml>=0.17.20
#   Downloading ruamel.yaml-0.17.21-py3-none-any.whl (109 kB)
#      |████████████████████████████████| 109 kB 89.2 MB/s
# Requirement already satisfied: tomli in /usr/local/lib/python3.7/dist-packages (from autopep8>=1.6.0->dglgo) (2.0.1)
# Collecting pycodestyle>=2.9.1
#   Downloading pycodestyle-2.9.1-py2.py3-none-any.whl (41 kB)
#      |████████████████████████████████| 41 kB 513 kB/s
# Requirement already satisfied: Jinja2>=2.10 in /usr/local/lib/python3.7/dist-packages (from numpydoc>=1.1.0->dglgo) (2.11.3)
# Collecting sphinx>=4.2
#   Downloading sphinx-5.3.0-py3-none-any.whl (3.2 MB)
#      |████████████████████████████████| 3.2 MB 78.0 MB/s
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2>=2.10->numpydoc>=1.1.0->dglgo) (2.0.1)
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.7/dist-packages (from ogb>=1.3.3->dglgo) (1.3.5)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from ogb>=1.3.3->dglgo) (1.15.0)
# Collecting outdated>=0.2.0
#   Downloading outdated-0.2.2-py2.py3-none-any.whl (7.5 kB)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from ogb>=1.3.3->dglgo) (1.12.1+cu113)
# Collecting littleutils
#   Downloading littleutils-0.2.2.tar.gz (6.6 kB)
# Requirement already satisfied: setuptools>=44 in /usr/local/lib/python3.7/dist-packages (from outdated>=0.2.0->ogb>=1.3.3->dglgo) (57.4.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->ogb>=1.3.3->dglgo) (2022.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->ogb>=1.3.3->dglgo) (2.8.2)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.7/dist-packages (from pydantic>=1.9.0->dglgo) (4.1.1)
# Collecting ruamel.yaml.clib>=0.2.6
#   Downloading ruamel.yaml.clib-0.2.7-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (500 kB)
#      |████████████████████████████████| 500 kB 77.8 MB/s
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.20.0->dglgo) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.20.0->dglgo) (1.2.0)
# Collecting Jinja2>=2.10
#   Downloading Jinja2-3.1.2-py3-none-any.whl (133 kB)
#      |████████████████████████████████| 133 kB 90.4 MB/s
# Collecting sphinxcontrib-jsmath
#   Downloading sphinxcontrib_jsmath-1.0.1-py2.py3-none-any.whl (5.1 kB)
# Collecting sphinxcontrib-qthelp
#   Downloading sphinxcontrib_qthelp-1.0.3-py2.py3-none-any.whl (90 kB)
#      |████████████████████████████████| 90 kB 12.4 MB/s
# Requirement already satisfied: imagesize>=1.3 in /usr/local/lib/python3.7/dist-packages (from sphinx>=4.2->numpydoc>=1.1.0->dglgo) (1.4.1)
# Requirement already satisfied: importlib-metadata>=4.8 in /usr/local/lib/python3.7/dist-packages (from sphinx>=4.2->numpydoc>=1.1.0->dglgo) (4.13.0)
# Collecting sphinxcontrib-htmlhelp>=2.0.0
#   Downloading sphinxcontrib_htmlhelp-2.0.0-py2.py3-none-any.whl (100 kB)
#      |████████████████████████████████| 100 kB 12.3 MB/s
# Requirement already satisfied: packaging>=21.0 in /usr/local/lib/python3.7/dist-packages (from sphinx>=4.2->numpydoc>=1.1.0->dglgo) (21.3)
# Requirement already satisfied: docutils<0.20,>=0.14 in /usr/local/lib/python3.7/dist-packages (from sphinx>=4.2->numpydoc>=1.1.0->dglgo) (0.17.1)
# Requirement already satisfied: snowballstemmer>=2.0 in /usr/local/lib/python3.7/dist-packages (from sphinx>=4.2->numpydoc>=1.1.0->dglgo) (2.2.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.5 in /usr/local/lib/python3.7/dist-packages (from sphinx>=4.2->numpydoc>=1.1.0->dglgo) (1.1.5)
# Requirement already satisfied: babel>=2.9 in /usr/local/lib/python3.7/dist-packages (from sphinx>=4.2->numpydoc>=1.1.0->dglgo) (2.10.3)
# Collecting Pygments>=2.12
#   Downloading Pygments-2.13.0-py3-none-any.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 77.6 MB/s
# Requirement already satisfied: alabaster<0.8,>=0.7 in /usr/local/lib/python3.7/dist-packages (from sphinx>=4.2->numpydoc>=1.1.0->dglgo) (0.7.12)
# Collecting sphinxcontrib-applehelp
#   Downloading sphinxcontrib_applehelp-1.0.2-py2.py3-none-any.whl (121 kB)
#      |████████████████████████████████| 121 kB 90.8 MB/s
# Collecting sphinxcontrib-devhelp
#   Downloading sphinxcontrib_devhelp-1.0.2-py2.py3-none-any.whl (84 kB)
#      |████████████████████████████████| 84 kB 4.4 MB/s
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.8->sphinx>=4.2->numpydoc>=1.1.0->dglgo) (3.10.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=21.0->sphinx>=4.2->numpydoc>=1.1.0->dglgo) (3.0.9)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.7/dist-packages (from typer>=0.4.0->dglgo) (7.1.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.7/dist-packages (from rdkit-pypi->dglgo) (7.1.2)
# Building wheels for collected packages: littleutils
#   Building wheel for littleutils (setup.py) ... done
#   Created wheel for littleutils: filename=littleutils-0.2.2-py3-none-any.whl size=7048 sha256=87a62d6780b1199fff180c76b46075cf11563252291946db50556f3a258cf10b
#   Stored in directory: /root/.cache/pip/wheels/d6/64/cd/32819b511a488e4993f2fab909a95330289c3f4e0f6ef4676d
# Successfully built littleutils
# Installing collected packages: sphinxcontrib-qthelp, sphinxcontrib-jsmath, sphinxcontrib-htmlhelp, sphinxcontrib-devhelp, sphinxcontrib-applehelp, Pygments, littleutils, Jinja2, sphinx, ruamel.yaml.clib, pycodestyle, outdated, ruamel.yaml, rdkit-pypi, psutil, ogb, numpydoc, isort, autopep8, dglgo, dgl-cu113
#   Attempting uninstall: Pygments
#     Found existing installation: Pygments 2.6.1
#     Uninstalling Pygments-2.6.1:
#       Successfully uninstalled Pygments-2.6.1
#   Attempting uninstall: Jinja2
#     Found existing installation: Jinja2 2.11.3
#     Uninstalling Jinja2-2.11.3:
#       Successfully uninstalled Jinja2-2.11.3
#   Attempting uninstall: sphinx
#     Found existing installation: Sphinx 1.8.6
#     Uninstalling Sphinx-1.8.6:
#       Successfully uninstalled Sphinx-1.8.6
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.4.8
#     Uninstalling psutil-5.4.8:
#       Successfully uninstalled psutil-5.4.8
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.9.0 requires jedi>=0.10, which is not installed.
# flask 1.1.4 requires Jinja2<3.0,>=2.10.1, but you have jinja2 3.1.2 which is incompatible.
# Successfully installed Jinja2-3.1
device='cuda:0', dtype=torch.float64)
# Inference MACs:[777.52M]
# Sparsity in gc1.weight: 0.00%
# Sparsity in gc2.weight: 0.00%
# Weight Sparsity: 0.00%
# Sparsity in gc1.bias: 0.00%
# Sparsity in gc2.bias: 0.00%
# Sparsity in adj_weight: 0.00%
# Sparsity in adj_matrix: 99.98%
# Sparsity in adj_mask: 99.98%
# Prune adj percent: 0.00%
# Epoch: 0004 loss_train: 1.1281 acc_train: 0.4000 loss_val: 1.1814 acc_val: 0.2840 time: 0.9824s
# Best val acc: tensor(0.2840, device='cuda:0', dtype=torch.float64)
# Inference MACs:[777.52M]
# Sparsity in gc1.weight: 0.00%
# Sparsity in gc2.weight: 0.00%
# Weight Sparsity: 0.00%
# Sparsity in gc1.bias: 0.00%
# Sparsity in gc2.bias: 0.00%
# Sparsity in adj_weight: 0.00%
# Sparsity in adj_matrix: 99.98%
# Sparsity in adj_mask: 99.98%
# Prune adj percent: 0.00%
# Epoch: 0005 loss_train: 1.1273 acc_train: 0.4333 loss_val: 1.1688 acc_val: 0.3640 time: 0.9753s
# Best val acc: tensor(0.3640, device='cuda:0', dtype=torch.float64)
# Inference MACs:[777.52M]
# Sparsity in gc1.weight: 0.00%
# Sparsity in gc2.weight: 0.00%
# Weight Sparsity: 0.00%
# Sparsity in gc1.bias: 0.00%
# Sparsity in gc2.bias: 0.00%
# Sparsity in adj_weight: 0.00%
# Sparsity in adj_matrix: 99.98%
# Sparsity in adj_mask: 99.98%
# Prune adj percent: 0.00%
# Epoch: 0006 loss_train: 1.1144 acc_train: 0.3833 loss_val: 1.1571 acc_val: 0.4400 time: 0.9715s
# Best val acc: tensor(0.4400, device='cuda:0', dtype=torch.float64)
# Inference MACs:[777.52M]
# Sparsity in gc1.weight: 0.00%
# Sparsity in gc2.weight: 0.00%
# Weight Sparsity: 0.00%
# Sparsity in gc1.bias: 0.00%
# Sparsity in gc2.bias: 0.00%
# Sparsity in adj_weight: 0.00%
# Sparsity in adj_matrix: 99.98%
# Sparsity in adj_mask: 99.98%
# Prune adj percent: 0.00%
# Epoch: 0007 loss_train: 1.1076 acc_train: 0.4000 loss_val: 1.1459 acc_val: 0.4840 time: 0.9771s
# Best val acc: tensor(0.4840, device='cuda:0', dtype=torch.float64)
# Inference MACs:[777.52M]
# Sparsity in gc1.weight: 0.00%
# Sparsity in gc2.weight: 0.00%
# Weight Sparsity: 0.00%
# Sparsity in gc1.bias: 0.00%
# Sparsity in gc2.bias: 0.00%
# Sparsity in adj_weight: 0.00%
# Sparsity in adj_matrix: 99.98%
# Sparsity in adj_mask: 99.98%
# Prune adj percent: 0.00%
# Epoch: 0008 loss_train: 1.0920 acc_train: 0.4833 loss_val: 1.1345 acc_val: 0.5180 time: 0.9745s
# Best val acc: tensor(0.5180, device='cuda:0', dtype=torch.float64)
# Inference MACs:[777.52M]
# Sparsity in gc1.weight: 0.00%
# Sparsity in gc2.weight: 0.00%
# Weight Sparsity: 0.00%
# Sparsity in gc1.bias: 0.00%
# Sparsity in gc2.bias: 0.00%
# Sparsity in adj_weight: 0.00%
# Sparsity in adj_matrix: 99.98%
# Sparsity in adj_mask: 99.98%
# Prune adj percent: 0.00%
# Epoch: 0009 loss_train: 1.0868 acc_train: 0.5333 loss_val: 1.1232 acc_val: 0.5220 time: 0.9729s
# Best val acc: tensor(0.5220, device='cuda:0', dtype=torch.float64)
# Inference MACs:[777.52M]
# Sparsity in gc1.weight: 0.00%
# Sparsity in gc2.weight: 0.00%
# Weight Sparsity: 0.00%
# Sparsity in gc1.bias: 0.00%
# Sparsity in gc2.bias: 0.00%
# Sparsity in adj_weight: 0.00%
# Sparsity in adj_matrix: 99.98%
# Sparsity in adj_mask: 99.98%
# Prune adj percent: 0.00%
# Epoch: 0010 loss_train: 1.0779 acc_train: 0.5333 loss_val: 1.1125 acc_val: 0.5340 time: 0.9730s
# Best val acc: tensor(0.5340, device='cuda:0', dtype=torch.float64)
# Inference MACs:[777.52M]
# Sparsity in gc1.weight: 0.00%
# Sparsity in gc2.weight: 0.00%
# Weight Sparsity: 0.00%
# Sparsity in gc1.bias: 0.00%
# Sparsity in gc2.bias: 0.00%
# Sparsity in adj_weight: 0.00%
# Sparsity in adj_matrix: 99.98%
# Sparsity in adj_mask: 99.98%
# Prune adj percent: 0.00%
# Optimization Finished!
# Total time elapsed: 11.9042s
# Test set results: loss= 1.1090 accuracy= 0.5190
# --------------Pruning--------------
# --------------Post training GCN--------------
# Epoch: 0001 loss_train: 1.1701 acc_train: 0.3333 loss_val: 1.2240 acc_val: 0.1960 time: 0.8851s
# Best val acc: tensor(0.1960, device='cuda:0', dtype=torch.float64)
# Inference MACs:[388.76M]
# Sparsity in gc1.weight: 0.00%
# Sparsity in gc2.weight: 0.00%
# Weight Sparsity: 0.00%
# Sparsity in gc1.bias: 0.00%
# Sparsity in gc2.bias: 0.00%
# Sparsity in adj_weight: 0.00%
# Sparsity in adj_matrix: 99.98%
# Sparsity in adj_mask: 100.00%
# Prune adj percent: 90.00%
# Epoch: 0002 loss_train: 1.1507 acc_train: 0.3333 loss_val: 1.2071 acc_val: 0.2080 time: 0.8905s
# Best val acc: tensor(0.2080, device='cuda:0', dtype=torch.float64)
# Inference MACs:[388.76M]
# Sparsity in gc1.weight: 0.00%
# Sparsity in gc2.weight: 0.00%
# Weight Sparsity: 0.00%
# Sparsity in gc1.bias: 0.00%
# Sparsity in gc2.bias: 0.00%
# Sparsity in adj_weight: 0.00%
# Sparsity in adj_matrix: 99.98%
# Sparsity in adj_mask: 100.00%
# Prune adj percent: 90.00%
# Epoch: 0003 loss_train: 1.1395 acc_train: 0.3667 loss_val: 1.1912 acc_val: 0.2620 time: 0.8866s
# Best val acc: tensor(0.2620, device='cuda:0', dtype=torch.float64)
# Inference MACs:[388.76M]
# Sparsity in gc1.weight: 0.00%
# Sparsity in gc2.weight: 0.00%
# Weight Sparsity: 0.00%
# Sparsity in gc1.bias: 0.00%
# Sparsity in gc2.bias: 0.00%
# Sparsity in adj_weight: 0.00%
# Sparsity in adj_matrix: 99.98%
# Sparsity in adj_mask: 100.00%
# Prune adj percent: 90.00%
# Epoch: 0004 loss_train: 1.1295 acc_train: 0.4167 loss_val: 1.1762 acc_val: 0.3500 time: 0.8853s
# Best val acc: tensor(0.3500, device='cuda:0', dtype=torch.float64)
# Inference MACs:[388.76M]
# Sparsity in gc1.weight: 0.00%
# Sparsity in gc2.weight: 0.00%
# Weight Sparsity: 0.00%
# Sparsity in gc1.bias: 0.00%
# Sparsity in gc2.bias: 0.00%
# Sparsity in adj_weight: 0.00%
# Sparsity in adj_matrix: 99.98%
# Sparsity in adj_mask: 100.00%
# Prune adj percent: 90.00%
# Epoch: 0005 loss_train: 1.1158 acc_train: 0.3833 loss_val: 1.1611 acc_val: 0.4320 time: 0.8820s
# Best val acc: tensor(0.4320, device='cuda:0', dtype=torch.float64)
# Inference MACs:[388.76M]
# Sparsity in gc1.weight: 0.00%
# Sparsity in gc2.weight: 0.00%
# Weight Sparsity: 0.00%
# Sparsity in gc1.bias: 0.00%
# Sparsity in gc2.bias: 0.00%
# Sparsity in adj_weight: 0.00%
# Sparsity in adj_matrix: 99.98%
# Sparsity in adj_mask: 100.00%
# Prune adj percent: 90.00%
# Epoch: 0006 loss_train: 1.1089 acc_train: 0.4667 loss_val: 1.1466 acc_val: 0.4700 time: 0.8839s
# Best val acc: tensor(0.4700, device='cuda:0', dtype=torch.float64)
# Inference MACs:[388.76M]
# Sparsity in gc1.weight: 0.00%
# Sparsity in gc2.weight: 0.00%
# Weight Sparsity: 0.00%
# Sparsity in gc1.bias: 0.00%
# Sparsity in gc2.bias: 0.00%
# Sparsity in adj_weight: 0.00%
# Sparsity in adj_matrix: 99.98%
# Sparsity in adj_mask: 100.00%
# Prune adj percent: 90.00%
# Epoch: 0007 loss_train: 1.0976 acc_train: 0.4667 loss_val: 1.1325 acc_val: 0.4920 time: 0.8867s
# Best val acc: tensor(0.4920, device='cuda:0', dtype=torch.float64)
# Inference MACs:[388.76M]
# Sparsity in gc1.weight: 0.00%
# Sparsity in gc2.weight: 0.00%
# Weight Sparsity: 0.00%
# Sparsity in gc1.bias: 0.00%
# Sparsity in gc2.bias: 0.00%
# Sparsity in adj_weight: 0.00%
# Sparsity in adj_matrix: 99.98%
# Sparsity in adj_mask: 100.00%
# Prune adj percent: 90.00%
# Epoch: 0008 loss_train: 1.1016 acc_train: 0.4833 loss_val: 1.1186 acc_val: 0.5100 time: 0.8792s
# Best val acc: tensor(0.5100, device='cuda:0', dtype=torch.float64)
# Inference MACs:[388.76M]
# Sparsity in gc1.weight: 0.00%
# Sparsity in gc2.weight: 0.00%
# Weight Sparsity: 0.00%
# Sparsity in gc1.bias: 0.00%
# Sparsity in gc2.bias: 0.00%
# Sparsity in adj_weight: 0.00%
# Sparsity in adj_matrix: 99.98%
# Sparsity in adj_mask: 100.00%
# Prune adj percent: 90.00%
# Epoch: 0009 loss_train: 1.0788 acc_train: 0.5333 loss_val: 1.1047 acc_val: 0.5160 time: 0.9552s
# Best val acc: tensor(0.5160, device='cuda:0', dtype=torch.float64)
# Inference MACs:[388.76M]
# Sparsity in gc1.weight: 0.00%
# Sparsity in gc2.weight: 0.00%
# Weight Sparsity: 0.00%
# Sparsity in gc1.bias: 0.00%
# Sparsity in gc2.bias: 0.00%
# Sparsity in adj_weight: 0.00%
# Sparsity in adj_matrix: 99.98%
# Sparsity in adj_mask: 100.00%
# Prune adj percent: 90.00%
# Epoch: 0010 loss_train: 1.0688 acc_train: 0.4833 loss_val: 1.0914 acc_val: 0.5260 time: 1.0068s
# Best val acc: tensor(0.5260, device='cuda:0', dtype=torch.float64)
# Inference MACs:[388.76M]
# Sparsity in gc1.weight: 0.00%
# Sparsity in gc2.weight: 0.00%
# Weight Sparsity: 0.00%
# Sparsity in gc1.bias: 0.00%
# Sparsity in gc2.bias: 0.00%
# Sparsity in adj_weight: 0.00%
# Sparsity in adj_matrix: 99.98%
# Sparsity in adj_mask: 100.00%
# Prune adj percent: 90.00%
# Optimization Finished!
# Total time elapsed: 9.3214s
# Test set results: loss= 1.0901 accuracy= 0.5230
